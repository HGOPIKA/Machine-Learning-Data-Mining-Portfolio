# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
#this will make your plot outputs appear and be stored within the notebook

# %%
data = pd.read_csv("IceCreamData.csv")

# %%
data.head()
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122
# 2    27.790554  660.632289
# 3    20.595335  487.706960
# 4    11.503498  316.240194

# %%
data.keys() #Print the attributes
# Out:
# Index(['Temperature', 'Revenue'], dtype='object')

# %%
data.describe() #Data description
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.232225   521.570777
# std       8.096388   175.404751
# min       0.000000    10.000000
# 25%      17.122258   405.558681
# 50%      22.392791   529.368565
# 75%      27.740674   642.257922
# max      45.000000  1000.000000

# %%
print("Missing values in the entire dataframe\n")
data.isnull().sum().sum()
# Out:
# Missing values in the entire dataframe
# 0

# %%
data.dtypes #Data Type
# Out:
# Temperature    float64
# Revenue        float64
# dtype: object

# %%
# Display how Sales are related with other variables using scatter plot.
import seaborn as sns
sns.pairplot(data, x_vars=['Temperature'], y_vars='Revenue', aspect=1, kind='scatter')
plt.show()
# Out:
# C:\Users\gopika\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Display the correlation between different variables.
sns.heatmap(data.corr(), cmap="YlGnBu", annot = True)
plt.show()

# %%
x = data.iloc[:,0].values.reshape(-1,1)    # predictor attribute
y = data.iloc[:,-1].values.reshape(-1,1) # target attribute

# %%
#To view the value of x
data.iloc[:,:-1].values    # predictor attribute
# Out:
# array([[24.56688442],
#        [26.00519115],
#        [27.79055388],
#        [20.59533505],
#        [11.50349764],
#        [14.35251388],
#        [13.70777988],
#        [30.83398474],
#        [ 0.97686999],
#        [31.66946458],
#        [11.45525338],
#        [ 3.66466958],
#        [18.81182403],
#        [13.62450892],
#        [39.53990899],
#        [18.48314099],
#        [25.93537514],
#        [42.51528041],
#        [29.58948056],
#        [21.77594799],
#        [25.45783637],
#        [15.21456942],
#        [22.61931574],
#        [16.25872074],
#        [23.88172478],
#        [18.97830025],
#        [15.6614643 ],
#        [29.18504465],
#        [19.02461092],
#        [35.12015142],
#        [24.18393726],
#        [15.23119012],
#        [ 8.79095281],
#        [18.23322784],
#        [35.62892497],
#        [37.05754246],
#        [22.28455032],
#        [17.51707397],
#        [31.7379196 ],
#        [17.04973761],
#        [23.0034888 ],
# ...

# %%
#To view the value of y
data.iloc[:,-1].values        # target attribute
# Out:
# array([ 534.7990284 ,  625.1901215 ,  660.6322888 ,  487.7069603 ,
#         316.2401944 ,  367.9407438 ,  308.8945179 ,  696.7166402 ,
#          55.39033824,  737.8008241 ,  325.9684084 ,   71.16015301,
#         467.4467066 ,  289.5409341 ,  905.4776043 ,  469.9090332 ,
#         648.2099977 ,  921.508275  ,  649.5611747 ,  534.6228653 ,
#         612.1539491 ,  353.3256334 ,  524.2361154 ,  374.231135  ,
#         523.1245467 ,  473.6043349 ,  402.4553204 ,  679.3177906 ,
#         517.5340283 ,  809.6720534 ,  528.3804165 ,  356.0980075 ,
#         237.7639106 ,  418.1372788 ,  809.4634112 ,  870.7659159 ,
#         550.2785159 ,  405.6614459 ,  740.9356848 ,  501.7329901 ,
#         539.6880057 ,  242.2362083 ,  421.621505  ,  358.0028493 ,
#         467.631063  ,  396.9356482 ,  500.9250645 ,  651.8615363 ,
#         451.4507843 ,  697.8339862 ,  190.7109408 ,  621.1897304 ,
#         666.1368355 ,  628.4532107 ,  219.3039932 ,  623.5988607 ,
# ...

# %%
# split the dataset into test set and train set
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test =train_test_split(x,y, test_size=0.25, random_state=0)

# %%
# import the Linear Regression model from scikit learn
from sklearn.linear_model import LinearRegression

# %%
#initialize the linear regression model
regressor=LinearRegression()
regressor
# Out:
# LinearRegression()

# %%
#fit the Linear Regression Model
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#result
y_pred=regressor.predict(x_test)
y_pred
# Out:
# array([[697.90290765],
#        [653.08862886],
#        [664.44466678],
#        [451.18999773],
#        [665.1857663 ],
#        [442.08017944],
#        [584.13991762],
#        [623.72233505],
#        [667.18925906],
#        [469.31377713],
#        [547.06808825],
#        [444.11436112],
#        [622.85253612],
#        [378.64244577],
#        [368.10403798],
#        [944.13074552],
#        [892.48727588],
#        [694.036143  ],
#        [546.29470101],
#        [421.38958715],
#        [392.02105395],
#        [597.03086138],
#        [284.65335923],
#        [655.25614744],
#        [381.96908957],
#        [413.15935937],
#        [372.07604898],
#        [510.64320368],
#        [480.24313138],
#        [457.32526676],
#        [639.94003185],
#        [283.07684505],
#        [315.46880983],
#        [470.59732064],
#        [559.90770919],
#        [540.02326027],
#        [309.03189011],
#        [509.0629905 ],
#        [571.56328305],
#        [731.66892287],
# ...

# %%
# Visualizing the Result (Training_Set)
plt.scatter(x_train,y_train, color= 'red')
plt.plot(x_train, regressor.predict(x_train), color= 'blue' )
plt.title('TV Sales')
plt.xlabel('Temperature')
plt.ylabel('Revenue')
plt.show()

# %%
# Visualizing the Result (Test Set)
plt.scatter(x_test,y_test, color='red')
plt.plot(x_test, regressor.predict(x_test), color='blue')
plt.title("Daily revenue")
plt.xlabel('TV')
plt.ylabel('Sales')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#To retrieve the intercept:
print(regressor.intercept_)

#For retrieving the slope:
print(regressor.coef_)
# Out:
# [46.22034113]
# [[21.41734668]]

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 18.39383836534172
# Mean Squared Error: 524.4821008905756
# Root Mean Squared Error: 22.901574201145554
